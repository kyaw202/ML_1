# %%
import tensorflow as tf
from tensorflow.keras import layers

# Load CIFAR-10 dataset
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.cifar10.load_data()

# Normalize the images to the range [0, 1]
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Convert labels to one-hot encoding if needed
y_train_one_hot = tf.keras.utils.to_categorical(y_train, 10)
y_test_one_hot = tf.keras.utils.to_categorical(y_test, 10)

# Print dataset shapes
print("Training data shape:", x_train.shape, y_train.shape)
print("Testing data shape:", x_test.shape, y_test.shape)
# Out:
# Training data shape: (50000, 32, 32, 3) (50000, 1)
# Testing data shape: (10000, 32, 32, 3) (10000, 1)

# %%
import numpy as np
def exclue_class(x_data,y_data, excluded_cindex):
    x_filtered,y_filtered = [],[]
    for cur_x, cur_y in zip(x_data,y_data):
        if np.argmax(cur_y) in excluded_cindex:
            continue
        x_filtered.append(cur_x)
        y_filtered.append(cur_y)
    return np.array(x_filtered),np.array(y_filtered)

# %%
def check_cindex(cur_y):
    temp = set()
    for x in cur_y:
        temp.add(np.argmax(x))
    return temp

# %%
x_train_1, y_train_1  = exclue_class(x_train, y_train_one_hot, excluded_cindex=[1, 3, 7])
print("y_train_1 : ",check_cindex(y_train_1))


x_train_2, y_train_2 = exclue_class(x_train, y_train_one_hot, excluded_cindex=[2, 5, 8])
print("y_train_2 : ",check_cindex(y_train_2))

x_train_3, y_train_3 = exclue_class(x_train, y_train_one_hot, excluded_cindex=[4, 6, 9])
print("y_train_3 : ",check_cindex(y_train_3))
# Out:
# y_train_1 :  {0, 2, 4, 5, 6, 8, 9}
# y_train_2 :  {0, 1, 3, 4, 6, 7, 9}
# y_train_3 :  {0, 1, 2, 3, 5, 7, 8}

# %%
x_test_1, y_test_1  = exclue_class(x_test, y_test_one_hot, excluded_cindex=[1, 3, 7])
print("y_test_1 : ",check_cindex(y_test_1))

x_test_2, y_test_2  = exclue_class(x_test, y_test_one_hot, excluded_cindex=[2, 5, 8])
print("y_test_2 : ",check_cindex(y_test_2))

x_test_3, y_test_3  = exclue_class(x_test, y_test_one_hot, excluded_cindex=[4,6,9])
print("y_test_3 : ",check_cindex(y_test_3))
# Out:
# y_test_1 :  {0, 2, 4, 5, 6, 8, 9}
# y_test_2 :  {0, 1, 3, 4, 6, 7, 9}
# y_test_3 :  {0, 1, 2, 3, 5, 7, 8}

# %%
def load_model(learning_rate: float = 0.001):
    # Define a simple CNN for CIFAR-10 and set Adam optimizer
    model = tf.keras.Sequential(
        [
            layers.Input(shape=(32, 32, 3)),
            layers.Conv2D(32, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Conv2D(64, kernel_size=(3, 3), activation="relu"),
            layers.MaxPooling2D(pool_size=(2, 2)),
            layers.Flatten(),
            layers.Dropout(0.5),
            layers.Dense(10, activation="softmax"),
        ]
    )
    model.compile(
        "adam",
        loss="categorical_crossentropy",
        metrics=["accuracy"],
    )
    return model

# %% [markdown]
# ### Fed Learning

# %%
from flwr.client import NumPyClient, ClientApp
from flwr.common import ndarrays_to_parameters, Context
from flwr.client import Client, ClientApp, NumPyClient
from flwr.server.strategy import FedAvg
from flwr.server import ServerApp, ServerConfig
from flwr.server import ServerAppComponents

# %%
class FlowerClient(NumPyClient):
    def __init__(
        self, model, data, epochs, batch_size, verbose
    ):
        self.model = model
        self.x_train, self.y_train, self.x_test, self.y_test = data
        self.epochs = epochs
        self.batch_size = batch_size
        self.verbose = verbose

    def fit(self, parameters, config):
        self.model.set_weights(parameters)
        self.model.fit(
            self.x_train,
            self.y_train,
            epochs=self.epochs,
            batch_size=self.batch_size,
            verbose=self.verbose,
        )
        return self.model.get_weights(), len(self.x_train), {}

    def evaluate(self, parameters, config):
        self.model.set_weights(parameters)
        loss, accuracy = self.model.evaluate(self.x_test, self.y_test, verbose=0)
        return loss, len(self.x_test), {"accuracy": accuracy}

# %% [markdown]
# ### mdoel Evaluation method

# %%
def evaluate_model(model,cur_x_test,cur_y_test):
    
    loss, accuracy = model.evaluate(cur_x_test,cur_y_test, verbose=0)
    return loss, accuracy

# %%
# Client function
def client_fn1(context: Context) -> Client:
    net = load_model()
    client_data = (x_train_1,y_train_1,x_test_1,y_test_1)
    epochs = 3,
    batch_size = 32,
    verbose =1
    return FlowerClient(net, client_data, epochs,batch_size,verbose).to_client()

# %%
client = ClientApp(client_fn1)

# %%
print("x_test_1" ,x_test_1.shape)
print("y_test_1 " , y_test_1.shape)
# Out:
# x_test_1 (7000, 32, 32, 3)
# y_test_1  (7000, 10)

# %%
net = load_model()
_, accuracy137 = evaluate_model(net, x_test_1,y_test_1)
print("test accuracy on [1,3,7]: ", accuracy137)
# Out:
# test accuracy on [1,3,7]:  0.11385714262723923

# %% [markdown]
# ### Define evaluate for model testing
# - The evaluate method evaluates the performance of the neural network model using the provided parameters and the test dataset (testset).

# %%
def evaluate(server_round, parameters, config):
    net = load_model()
    net.set_weights(parameters)

    _, accuracy137 = evaluate_model(net, x_test_1,y_test_1)
    _, accuracy258 = evaluate_model(net, x_test_2,y_test_2)
    _, accuracy469 = evaluate_model(net, x_test_3,y_test_3)

    print("test accuracy on [1,3,7]: ", accuracy137)
    print("test accuracy on [2,5,8]: ", accuracy258)
    print("test accuracy on [4,6,9]: ", accuracy469)

# %%
net = load_model()
params = ndarrays_to_parameters(net.get_weights())

def server_fn(context: Context):
    strategy = FedAvg(
        fraction_fit=1.0,
        fraction_evaluate=0.0,
        initial_parameters=params,
        evaluate_fn=evaluate,
    )
    config=ServerConfig(num_rounds=3)
    return ServerAppComponents(
        strategy=strategy,
        config=config,
    )

# %%
server = ServerApp(server_fn=server_fn)

# %%
from flwr.simulation import run_simulation
run_simulation(
    server_app=server,
    client_app=client,
    num_supernodes=3,
    #backend_config=backend_setup,
)
# Out:
# INFO :      Starting Flower ServerApp, config: num_rounds=3, no round_timeout
# INFO :
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      Evaluation returned no results (`None`)
# INFO :
# INFO :      [ROUND 1]
# test accuracy on [1,3,7]:  0.10842857509851456
# test accuracy on [2,5,8]:  0.04514285549521446
# test accuracy on [4,6,9]:  0.11242856830358505
# INFO :      configure_fit: strategy sampled 2 clients (out of 3)
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# INFO :      aggregate_fit: received 0 results and 2 failures
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# test accuracy on [1,3,7]:  0.10842857509851456
# test accuracy on [2,5,8]:  0.04514285549521446
# test accuracy on [4,6,9]:  0.11242856830358505
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# INFO :      aggregate_fit: received 0 results and 3 failures
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 3 clients (out of 3)
# test accuracy on [1,3,7]:  0.10842857509851456
# test accuracy on [2,5,8]:  0.04514285549521446
# test accuracy on [4,6,9]:  0.11242856830358505
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51582, ip=127.0.0.1, actor_id=a51a833ca4b919328260a8dc01000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16bd1b940>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     An exception was raised when processing a message by RayBackend
# ERROR :     ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51581, ip=127.0.0.1, actor_id=fd18cf2a79549566ba37e89801000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x16941b910>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# ERROR :     Traceback (most recent call last):
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/vce_api.py", line 112, in worker
#     out_mssg, updated_context = backend.process_message(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 186, in process_message
#     raise ex
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/server/superlink/fleet/vce/backend/raybackend.py", line 174, in process_message
#     ) = self.pool.fetch_result_and_return_actor_to_pool(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 477, in fetch_result_and_return_actor_to_pool
#     _, out_mssg, updated_context = ray.get(future)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/auto_init_hook.py", line 21, in auto_init_wrapper
#     return fn(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/client_mode_hook.py", line 103, in wrapper
#     return func(*args, **kwargs)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 2667, in get
#     values, debugger_breakpoint = worker.get_objects(object_refs, timeout=timeout)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/ray/_private/worker.py", line 864, in get_objects
#     raise value.as_instanceof_cause()
# ray.exceptions.RayTaskError(ClientAppException): ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 143, in __call__
#     return self._call(message, context)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client_app.py", line 126, in ffn
#     out_message = handle_legacy_message_from_msgtype(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/message_handler/message_handler.py", line 129, in handle_legacy_message_from_msgtype
#     fit_res = maybe_call_fit(
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/client.py", line 255, in maybe_call_fit
#     return client.fit(fit_ins)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/client/numpy_client.py", line 259, in _fit
#     results = self.numpy_client.fit(parameters, ins.config)  # type: ignore
#   File "/var/folders/xd/3z5vvpds0zxf_pypxd4cn3d80000gn/T/ipykernel_51499/590279789.py", line 13, in fit
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/utils/traceback_utils.py", line 122, in error_handler
#     raise e.with_traceback(filtered_tb) from None
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/keras/src/trainers/data_adapters/array_data_adapter.py", line 88, in __init__
#     self._size = int(math.ceil(num_samples / batch_size))
# TypeError: unsupported operand type(s) for /: 'int' and 'tuple'
#
# The above exception was the direct cause of the following exception:
#
# ray::ClientAppActor.run() (pid=51580, ip=127.0.0.1, actor_id=601868a99868ba54eeb72ee601000000, repr=<flwr.simulation.ray_transport.ray_actor.ClientAppActor object at 0x38f813970>)
#   File "/opt/anaconda3/envs/dev_env/lib/python3.10/site-packages/flwr/simulation/ray_transport/ray_actor.py", line 63, in run
#     raise ClientAppException(str(ex)) from ex
# flwr.client.client_app.ClientAppException:
# Exception ClientAppException occurred. Message: unsupported operand type(s) for /: 'int' and 'tuple'
#
# INFO :      aggregate_fit: received 0 results and 3 failures
# INFO :      configure_evaluate: no clients selected, skipping evaluation
# INFO :
# INFO :      [SUMMARY]
# INFO :      Run finished 3 round(s) in 21.31s
# INFO :
# test accuracy on [1,3,7]:  0.10842857509851456
# test accuracy on [2,5,8]:  0.04514285549521446
# test accuracy on [4,6,9]:  0.11242856830358505
